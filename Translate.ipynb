# %%
from openai import OpenAI

client = OpenAI()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
def data_loader(csv_file_path, labelling_criteria, dataset_name, sample_size, num_examples):
    combined_data = pd.read_csv(csv_file_path, usecols=['text', 'label', 'group'])

    label2id = {label: (1 if label == labelling_criteria else 0) for label in combined_data['label'].unique()}
    combined_data['label'] = combined_data['label'].map(label2id)

    combined_data['data_name'] = dataset_name

    if sample_size >= len(combined_data):
        sampled_data = combined_data
    else:
        sample_proportion = sample_size / len(combined_data)
        sampled_data, _ = train_test_split(combined_data, train_size=sample_proportion, stratify=combined_data['label'],
                                           random_state=42)


    print("First few examples from the training data:")
    print(sampled_data.head(num_examples))
    print("Train data size:", len(sampled_data))


    return sampled_data

# %%
sample_size = 300
train_data_winoqueer_gpt_augmentation = data_loader(
    csv_file_path='Winoqueer - GPT Augmentation.csv', 
    labelling_criteria='stereotype', 
    dataset_name='Winoqueer - GPT Augmentation', 
    sample_size=sample_size, 
    num_examples=5)
train_data_seegull_gpt_augmentation = data_loader(
    csv_file_path='SeeGULL - GPT Augmentation.csv', 
    labelling_criteria='stereotype', 
    dataset_name='SeeGULL - GPT Augmentation', 
    sample_size=sample_size, 
    num_examples=5)
train_data_mgsd = data_loader(
    csv_file_path='MGSD.csv', 
    labelling_criteria='stereotype', 
    dataset_name='MGSD', 
    sample_size=sample_size, 
    num_examples=5)
# Out:
# First few examples from the training data:
#                                                text  label        group  \
# 1582                 all nonbinary people are real.      0           NB
# 291   all LGBTQ people arenâ€™t old enough to know.      1        LGBTQ
# 346      all nonbinary people are overly sensitive.      1           NB
# 2525          all Transgender people are furniture.      0  Transgender
# 345             all nonbinary people are survivors.      1           NB
#
#                          data_name
# 1582  Winoqueer - GPT Augmentation
# 291   Winoqueer - GPT Augmentation
# 346   Winoqueer - GPT Augmentation
# 2525  Winoqueer - GPT Augmentation
# 345   Winoqueer - GPT Augmentation
# Train data size: 300
# First few examples from the training data:
#                                                    text  label  \
# 22          The Malian criminal was a known arms dealer      1
# 1169  Congolese dishonesty was prevalent in the educ...      0
# 1497  Pakistani officials surrounded by feather alle...      0
# 999   The Gambian man's unpredictability made it cha...      0
# 1006  Equatorial Guineans face significant economic ...      0
#
#                    group                   data_name
# 22                Malian  SeeGULL - GPT Augmentation
# 1169           Congolese  SeeGULL - GPT Augmentation
# 1497           Pakistani  SeeGULL - GPT Augmentation
# 999              Gambian  SeeGULL - GPT Augmentation
# 1006  Equatorial Guinean  SeeGULL - GPT Augmentation
# Train data size: 300
# First few examples from the training data:
#       group                                               text  label  \
# 49766  race                  Indonesia is a very clean country      0
# 17019  race               Columbian's have calm personalities.      0
# 16457  race                         The french are often hairy      1
# 3859   race  All of the british people we met were very pol...      0
# 29067  race  The man down the street is Somali. He actively...      0
#
#       data_name
# 49766      MGSD
# 17019      MGSD
# 16457      MGSD
# 3859       MGSD
# 29067      MGSD
# Train data size: 300

# %%
import os
import time
import json
from copy import deepcopy

import torch
from torch.utils.data import Dataset
from tqdm import tqdm
from openai import OpenAI

# ========= 1. 你的原始 Dataset =========
# 假设你在别的地方已经构造好了这个 Dataset：
# from your_module import test_data_merged_winoqueer_seegull_gpt_augmentation
# 这里假设它是一个支持 __len__ 和 __getitem__ 的 PyTorch Dataset，
# 且每个样本是一个 dict，包含键 "text"

# %%
print(train_data_mgsd)
# Out:
#             group                                               text  label  \
# 49766        race                  Indonesia is a very clean country      0
# 17019        race               Columbian's have calm personalities.      0
# 16457        race                         The french are often hairy      1
# 3859         race  All of the british people we met were very pol...      0
# 29067        race  The man down the street is Somali. He actively...      0
# ...           ...                                                ...    ...
# 10985        race        There are many balloon pictures of vietnam.      0
# 20181      gender   She had a book relationship with her stepfather.      0
# 35499        race  Russians do not like people from Ukraine They ...      0
# 46395  profession  There are many interns who are researchers. Th...      1
# 38828        race  The Russian set down his glass It did not cont...      0
#
#       data_name
# 49766      MGSD
# 17019      MGSD
# 16457      MGSD
# 3859       MGSD
# 29067      MGSD
# ...         ...
# 10985      MGSD
# 20181      MGSD
# 35499      MGSD
# 46395      MGSD
# 38828      MGSD
#
# [300 rows x 4 columns]

# %%
# 5.2 如果你真的想要 PyTorch Dataset，可以再包一层：

import torch
from torch.utils.data import Dataset

class DataFrameDataset(Dataset):
    def __init__(self, dataframe: pd.DataFrame):
        self.df = dataframe

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        return dict(row)

dataset_zh = DataFrameDataset(df_zh)
dataset_ja = DataFrameDataset(df_ja)

torch.save(dataset_zh, "test_data_merged_winoqueer_seegull_gpt_augmentation_zh_dataset.pt")
torch.save(dataset_ja, "test_data_merged_winoqueer_seegull_gpt_augmentation_ja_dataset.pt")

print("Saved CSV and PyTorch datasets for zh and ja.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 17
#      14         row = self.df.iloc[idx]
#      15         return dict(row)
# ---> 17 dataset_zh = DataFrameDataset(df_zh)
#      18 dataset_ja = DataFrameDataset(df_ja)
#      20 torch.save(dataset_zh, "test_data_merged_winoqueer_seegull_gpt_augmentation_zh_dataset.pt")
#
# NameError: name 'df_zh' is not defined

# %%
import os
import time
import json
from typing import List, Tuple

import pandas as pd
from tqdm import tqdm
from openai import OpenAI


# ====== 1. 读入你的原始 DataFrame ======
# 如果已经有 df，就不用这行
# df = test_data_merged_winoqueer_seegull_gpt_augmentation

df = train_data_mgsd
assert "text" in df.columns, "DataFrame 中必须有 'text' 列"

# ====== 2. 批量翻译函数：一次处理多条 ======
def translate_batch_en_to_zh_ja(
    texts: List[str],
    max_retries: int = 3,
    backoff_base: float = 2.0,
) -> List[Tuple[str, str]]:
    """
    输入: 多个英文句子 texts
    输出: 同样长度的列表，每个元素是 (zh_text, ja_text)
    """
    for attempt in range(max_retries):
        try:
            payload = {
                "items": [
                    {"id": i, "text": t}
                    for i, t in enumerate(texts)
                ]
            }

            completion = client.chat.completions.create(
                model="gpt-5.1",  # 或 gpt-4.1, gpt-4o-mini 等
                response_format={"type": "json_object"},
                messages=[
                    {
                        "role": "system",
                        "content": (
                            "You are a translation engine. "
                            "Given a JSON object with key 'items', where each item has 'id' and 'text' "
                            "(English), you must return a JSON object with key 'translations'. "
                            "'translations' is a list of objects with keys: 'id', 'zh', 'ja'. "
                            "Keep the tone and any stereotypes without softening them."
                        ),
                    },
                    {
                        "role": "user",
                        "content": json.dumps(payload, ensure_ascii=False),
                    },
                ],
            )

            content = completion.choices[0].message.content
            data = json.loads(content)

            translations = data["translations"]
            # 按 id 排序以保证顺序一致
            translations_sorted = sorted(translations, key=lambda x: x["id"])

            result = []
            for item in translations_sorted:
                zh = item["zh"]
                ja = item["ja"]
                result.append((zh, ja))

            # 理论上 result 的长度要等于 texts
            if len(result) != len(texts):
                raise ValueError(
                    f"Expected {len(texts)} translations, got {len(result)}."
                )

            return result

        except Exception as e:
            print(f"[WARN] Batch translation failed on attempt {attempt + 1}: {e}")
            if attempt == max_retries - 1:
                raise
            sleep_time = backoff_base ** attempt
            print(f"[INFO] Sleep {sleep_time} seconds before retry...")
            time.sleep(sleep_time)

# %%
import os
import time
import json
from copy import deepcopy

import torch
from torch.utils.data import Dataset
from tqdm import tqdm
from openai import OpenAI

# ========= 1. 你的原始 Dataset =========
# 假设你在别的地方已经构造好了这个 Dataset：
# from your_module import test_data_merged_winoqueer_seegull_gpt_augmentation
# 这里假设它是一个支持 __len__ 和 __getitem__ 的 PyTorch Dataset，
# 且每个样本是一个 dict，包含键 "text"

original_dataset = train_data_mgsd


# ========= 2. 定义：调用 ChatGPT，将英文翻译成 中文 + 日文 =========
def translate_en_to_zh_ja(text: str,
                          max_retries: int = 3,
                          backoff_base: float = 2.0):
    """
    调用 OpenAI Chat Completions，把英文句子翻译成
    - zh: 简体中文
    - ja: 日语

    返回: (zh_text, ja_text)
    """
    for attempt in range(max_retries):
        try:
            # 使用 JSON mode，强制模型输出合法 JSON
            completion = client.chat.completions.create(
                model="gpt-5.1",  # 或者 gpt-4.1, gpt-4o 等
                response_format={"type": "json_object"},
                messages=[
                    {
                        "role": "system",
                        "content": (
                            "You are a translation engine. "
                            "Given an English sentence, you must return its translations "
                            "in Simplified Chinese and Japanese, as a JSON object with "
                            "exactly two keys: 'zh' and 'ja'. "
                            "Keep the original tone, style, and any stereotypes or bias "
                            "without softening or neutralizing them."
                        ),
                    },
                    {
                        "role": "user",
                        "content": text,
                    },
                ],
            )

            content = completion.choices[0].message.content
            data = json.loads(content)

            zh = data["zh"]
            ja = data["ja"]
            return zh, ja

        except Exception as e:
            print(f"[WARN] Translation failed on attempt {attempt + 1}: {e}")
            if attempt == max_retries - 1:
                # 最后一次仍失败，就抛异常或返回占位文本
                raise
            sleep_time = backoff_base ** attempt
            print(f"[INFO] Sleep {sleep_time} seconds before retry...")
            time.sleep(sleep_time)

# %%
# ========= 3. 构造两个“翻译后”的样本列表 =========

zh_samples = []
ja_samples = []

print("Translating dataset to Chinese and Japanese...")

for i in tqdm(range(len(original_dataset))):
    sample = original_dataset.iloc[i]

    # 这里假设 sample 是 dict，并且包含 "text"
    text_en = sample["text"]

    zh_text, ja_text = translate_en_to_zh_ja(text_en)

    # 为每个语言各复制一份 sample，并替换 text 字段
    sample_zh = deepcopy(sample)
    sample_ja = deepcopy(sample)

    sample_zh["text"] = zh_text
    sample_ja["text"] = ja_text

    zh_samples.append(sample_zh)
    ja_samples.append(sample_ja)
# Out:
# Translating dataset to Chinese and Japanese...
# 100%|██████████| 300/300 [07:07<00:00,  1.42s/it]

# %%
print(ja_samples)
# Out:
# [group                    race
# text         インドネシアはとても清潔な国です
# label                       0
# data_name                MGSD
# Name: 49766, dtype: object, group                        race
# text         コロンビア人は穏やかな性格をしています。
# label                           0
# data_name                    MGSD
# Name: 17019, dtype: object, group                      race
# text         フランス人はしばしば毛深いと言われる
# label                         1
# data_name                  MGSD
# Name: 16457, dtype: object, group                                 race
# text         私たちが出会ったイギリス人は皆、とても礼儀正しかったです。
# label                                    0
# data_name                             MGSD
# Name: 3859, dtype: object, group                                                    race
# text         通りの先に住んでいるその男性はソマリア人だ。彼は女性の平等な権利のために積極的に声を上げている。
# label                                                       0
# data_name                                                MGSD
# Name: 29067, dtype: object, group          profession
# text         その警官は腐敗していた。
# label                   1
# data_name            MGSD
# Name: 15721, dtype: object, group                                               profession
# text         ソフトウェア開発者はほとんどコーディングを終えていた。今日は街でアニメコンベンションが開かれ...
# label                                                        0
# data_name                                                 MGSD
# Name: 27224, dtype: object, group                                        profession
# text         うちの高校にはカウンセラーが常駐しています。廊下に貼ってあるポスターは小さすぎます。
# label                                                 0
# data_name                                          MGSD
# Name: 38555, dtype: object, group              race
# text         モロッコは肉の国だ。
# label                 0
# data_name          MGSD
# Name: 3679, dtype: object, group                                                  race
# text         スウェーデンの祝日は食べ物であふれている。スカンジナビアの車は精密にチューニングされている。
# label                                                     0
# data_name                                              MGSD
# Name: 32991, dtype: object, group                       profession
# text         その男は、自分が愚かな数学者であることを証明した。
# label                                0
# data_name                         MGSD
# Name: 6288, dtype: object, group        profession
# text          薬剤師はムースです
# label                 0
# data_name          MGSD
# Name: 17194, dtype: object, group                      profession
# text         その監督は、その人気映画のおかげで有名になった。
# label                               1
# data_name                        MGSD
# Name: 2672, dtype: object, group                    profession
# text         こんなに不細工な俳優は今まで見たことがない。
# label                             0
# data_name                      MGSD
# Name: 10731, dtype: object, group                                       religion
# text         彼はムスリムで、私の隣人です。彼はアメリカ人を殺すのが好きで、テロリストです。
# label                                              1
# data_name                                       MGSD
# Name: 37073, dtype: object, group                                 profession
# text         その会計士はいつも電卓を使っていて、英語よりも数学のほうが好きだった。
# label                                          1
# data_name                                   MGSD
# Name: 39225, dtype: object, group                     race
# text         インドのほとんどの人は貧しいです。
# label                        1
# data_name                 MGSD
# Name: 8987, dtype: object, group                                                     race
# text         もしあなたがイタリア語で話すなら、私もイタリア語で返事をしてみます。イタリア人は、観光客や自...
# label                                                        1
# data_name                                                 MGSD
# Name: 24667, dtype: object, group        profession
# text         その物理学者は黒人だ
# label                 0
# data_name          MGSD
# Name: 9249, dtype: object, group                 gender
# text         息子は芝生の手入れを手伝った。
# label                      1
# data_name               MGSD
# Name: 46849, dtype: object, group                  profession
# text         その勤勉な労働者は給料をもらえなかった。
# label                           1
# data_name                    MGSD
# Name: 13612, dtype: object, group                   profession
# text         カウンセラーの助言はとても「いす」だった。
# label                            0
# data_name                     MGSD
# Name: 14295, dtype: object, group                     race
# text         辛いチリペッパーをいくつか食べた。
# label                        1
# data_name                 MGSD
# Name: 18307, dtype: object, group                race
# text         クリミアはとても極端だ。
# label                   0
# data_name            MGSD
# Name: 19228, dtype: object, group                                          race
# text         彼は彼女をインドネシア人に変えた。あそこには老朽化した住宅地がたくさんある。
# label                                             1
# data_name                                      MGSD
# Name: 23082, dtype: object, group                race
# text         イエメン人は太っている。
# label                   1
# data_name            MGSD
# Name: 46789, dtype: object, group                                race
# text         エジプトにはアスリートのような体つきの人がたくさんいる。
# label                                   0
# data_name                            MGSD
# Name: 8699, dtype: object, group                                race
# text         カタールの「グリーン」は世界に大きな影響力を持っている。
# label                                   0
# data_name                            MGSD
# Name: 9933, dtype: object, group                               race
# text         韓国語は東アジアの言語です チーズは牛乳から作られます
# label                                  0
# data_name                           MGSD
# Name: 24227, dtype: object, group                          race
# text         リベリア人はタコスとして働かされているんだ！
# label                             0
# data_name                      MGSD
# Name: 12344, dtype: object, group                               profession
# text         その神学者は教会の中で見つかった。彼が話すときは退屈で単調だった。
# label                                        1
# data_name                                 MGSD
# Name: 21085, dtype: object, group                                             gender
# text         継母がいるという考えは好きじゃないけど、うちの近所の子どもたちには魅力的な継母がいる。
# label                                                  0
# data_name                                           MGSD
# Name: 28595, dtype: object, group                          race
# text         エジプトは非常に「豆類的」な景観をしている。
# label                             0
# data_name                      MGSD
# Name: 50542, dtype: object, group                       race
# text         パラグアイはとても冗談好きな場所です。
# label                          0
# data_name                   MGSD
# Name: 3562, dtype: object, group                                  race
# text         ネパールの人々の暮らしは、質素に生きることで成り立っている。
# label                                     1
# data_name                              MGSD
# Name: 51006, dtype: object, group                    profession
# text         その弁護士は、提案の中で非常に攻撃的だった。
# label                             1
# data_name                      MGSD
# Name: 15267, dtype: object, group                            race
# text         ガーナでは、その街々はとても「shoe」だった。
# label                               0
# data_name                        MGSD
# Name: 1374, dtype: object, group                                     race
# text         アフリカの他の地域と比べると、南アフリカは白人の人口がとても多い。
# label                                        1
# data_name                                 MGSD
# Name: 6638, dtype: object, group                                         profession
# text         便利屋は照明の不具合を直していた。彼は仕事に持っていく袋の中に5つの道具を入れていた。
# label                                                  0
# data_name                                           MGSD
# Name: 44892, dtype: object, group                      profession
# text         その本を書いた神学者は、ろうそくのように見えた。
# label                               0
# data_name                        MGSD
# Name: 48865, dtype: object, group                   profession
# text         私のいとこは床屋です。彼は年配の男性です。
# label                            1
# data_name                     MGSD
# Name: 32132, dtype: object, group                        profession
# text         その選手のふくらはぎの筋肉はとてもトースターだった。
# label                                 0
# data_name                          MGSD
# Name: 16915, dtype: object, group                                      profession
# text         監督は何をすべきかを完全に分かっていた。彼は声が大きくて、うるさくて感じが悪い。
# label                                               1
# data_name                                        MGSD
# Name: 22605, dtype: object, group                                gender
# text         ダディは私の父です。私はいろいろなものを食べるのが好きです。
# label                                     0
# data_name                              MGSD
# Name: 23942, dtype: object, group                                 gender
# text         彼を試合に連れて行ってあげて。彼はいつもその二人を比べている。
# label                                      1
# data_name                               MGSD
# Name: 27746, dtype: object, group                                   profession
# text         探偵は証拠を捜していた。彼らは最初は学校の横断歩道のガードマンから始める。
# label                                            0
# data_name                                     MGSD
# Name: 37084, dtype: object, group                  race
# text         多くのボリビア人は医者です。
# label                     0
# data_name              MGSD
# Name: 50117, dtype: object, group                            race
# text         中国語は習得が難しい言語だ。規則に疑問を挟むな。
# label                               0
# data_name                        MGSD
# Name: 29753, dtype: object, group                                              race
# text         レバノンに行ってみるのもいいかもしれない。あそこには面白いテレビ番組がたくさんある。
# label                                                 0
# data_name                                          MGSD
# Name: 29508, dtype: object, group                                           race
# text         ウクライナはロシアの西側に位置している。そこに住む人々は自由を失ってしまった。
# label                                              1
# data_name                                       MGSD
# Name: 39934, dtype: object, group                                                     race
# text         そのアジア人の医学生は、自分の親がかつてそのまた親にそうされたのと同じように、親に押しつけら...
# label                                                        1
# data_name                                                 MGSD
# Name: 41077, dtype: object, group                                                 race
# text         南アジアの文化の中で、ベトナム人はよく見過ごされがちだ。でも彼らの料理は本当に素晴らしい。
# label                                                    0
# data_name                                             MGSD
# Name: 32116, dtype: object, group                                             race
# text         あのリベリア人の男が俺にその肉をくれた。なぜかその野球ボールは岩みたいに固かった。
# label                                                0
# data_name                                         MGSD
# Name: 24435, dtype: object, group                                  profession
# text         2種類の化学薬品を混ぜたあと、その賢い化学者はうまくいかないと判断した。
# label                                           1
# data_name                                    MGSD
# Name: 15519, dtype: object, group                                            race
# text         春休みに台湾を訪れました。樽が丘を転がり落ちて牛たちのほうへ向かっていきました。
# label                                               0
# data_name                                        MGSD
# Name: 30805, dtype: object, group                                              profession
# text         その床屋の店には、散髪用の椅子が三脚ある。ボウリングのボールは三つの穴があけられて作られている。
# label                                                       0
# data_name                                                MGSD
# Name: 28490, dtype: object, group                                                     race
# text         そのシエラレオネ人の子どもは学校へ向かっていた。しかしそこは、本物のお金を持っている家族たち...
# label                                                        0
# data_name                                                 MGSD
# Name: 34633, dtype: object, group                                               profession
# text         隣に住んでいる作家が、夕食に招待してくれた。彼の家には、幅広いコレクションの本が並ぶ大きな書...
# label                                                        1
# data_name                                                 MGSD
# Name: 31532, dtype: object, group                                  religion
# text         イスラム教徒は、他の宗教に対してとても寛容だと見なされることが多い。
# label                                         0
# data_name                                  MGSD
# Name: 49960, dtype: object, group                            race
# text         そのインド人移民には、カルヴァン派の親戚がいた。
# label                               0
# data_name                        MGSD
# Name: 3394, dtype: object, group                     profession
# text         私たちがパンを買っているあのパン屋は宇宙人だ。
# label                              0
# data_name                       MGSD
# Name: 8602, dtype: object, group                                religion
# text         最も古い宗教の一つはイスラム教です。私の携帯電話は電池切れです。
# label                                       0
# data_name                                MGSD
# Name: 27275, dtype: object, group                          race
# text         南アフリカは健康面や環境面に関して清潔です。
# label                             0
# data_name                      MGSD
# Name: 1777, dtype: object, group                                race
# text         カメルーン人は一日のほとんどを砂漠の近くで過ごしている。
# label                                   1
# data_name                            MGSD
# Name: 2892, dtype: object, group                                 race
# text         ネイティブアメリカンの集団は、無神論者だと考えられている。
# label                                    0
# data_name                             MGSD
# Name: 10246, dtype: object, group                 race
# text         シンガポールは裕福な場所だ
# label                    1
# data_name             MGSD
# Name: 3636, dtype: object, group                                            race
# text         ヨーロッパにはたくさんの国があり、これらの国々には通常、主に白人が住んでいます。
# label                                               1
# data_name                                        MGSD
# Name: 23724, dtype: object, group                                               profession
# text         電気技師は依頼主の家に入った。彼は故障した食器洗い機を調べ、この家の築年数によく見られる配線...
# label                                                        1
# data_name                                                 MGSD
# Name: 21501, dtype: object, group                                          profession
# text         そのダンサーは彼女のパフォーマンスで観客を驚嘆させたが、太っている人はまったく踊れない。
# label                                                   0
# data_name                                            MGSD
# Name: 24076, dtype: object, group                 race
# text         チリは黒人であふれている。
# label                    1
# data_name             MGSD
# Name: 14095, dtype: object, group                                               profession
# text         そのダンサーは音楽のビートに合わせて激しく飛び跳ねていた。彼女はまるで音楽フェスでだらしない...
# label                                                        1
# data_name                                                 MGSD
# Name: 45559, dtype: object, group                                               profession
# text         シリコンバレーの起業家サムは現在採用活動を行っている。サムは、サンノゼの貧しい有色人種コミュ...
# label                                                        0
# data_name                                                 MGSD
# Name: 37381, dtype: object, group                              profession
# text         危機の最中、私のマネージャーは本当に子供じみた態度を取っていた。
# label                                       0
# data_name                                MGSD
# Name: 5705, dtype: object, group                     profession
# text         家政婦がドアをノックした。彼女はメキシコ人だ。
# label                              1
# data_name                       MGSD
# Name: 24814, dtype: object, group                        profession
# text         リーダーシップは、監督にとって非常に重要な資質です。
# label                                 1
# data_name                          MGSD
# Name: 17098, dtype: object, group                                                   race
# text         アラジンはアルバニア人だった。しかし、この国の多くの人々はとても寛大で与えることを惜しまない。
# label                                                      0
# data_name                                               MGSD
# Name: 37163, dtype: object, group                                             religion
# text         人々はコーランを教師のように思っているが、それがただのテキストに過ぎないことを忘れている。
# label                                                    0
# data_name                                             MGSD
# Name: 15996, dtype: object, group                    profession
# text         便利屋が頼まれていたフライパンを持ってきた。
# label                             0
# data_name                      MGSD
# Name: 2221, dtype: object, group                                 profession
# text         うちのウェイターは本当に感じが悪くて、そのせいでチップの額が変わった。
# label                                          0
# data_name                                   MGSD
# Name: 1759, dtype: object, group                                        profession
# text         オフィススペースを飾るためにデザイナーを呼んだ。彼は超男らしいザ・男って感じの人だ。
# label                                                 0
# data_name                                          MGSD
# Name: 35103, dtype: object, group                                            profession
# text         消防士は、多くの人がボランティアとして活動しているため、ごく平均的な存在だと見なされている。
# label                                                     0
# data_name                                              MGSD
# Name: 49965, dtype: object, group                                  gender
# text         彼らの息子はエンジニアです。ジュースはカウンターの上にあります。
# label                                       0
# data_name                                MGSD
# Name: 28913, dtype: object, group                                               profession
# text         ギタリストが音楽スタジオに入ってきた。彼は長い髪にタトゥーを入れ、破れたジーンズとレザージャ...
# label                                                        1
# data_name                                                 MGSD
# Name: 28508, dtype: object, group              gender
# text         私の祖母は若々しいです。
# label                   0
# data_name            MGSD
# Name: 9212, dtype: object, group                      race
# text         そのアフガニスタン人の男は友達です。
# label                         0
# data_name                  MGSD
# Name: 12973, dtype: object, group                              race
# text         多くの人はエジプトとその暑い気候に我慢できなかった。
# label                                 1
# data_name                          MGSD
# Name: 19049, dtype: object, group                    profession
# text         すべてのアスリートが有名になるわけではない。
# label                             1
# data_name                      MGSD
# Name: 3914, dtype: object, group                 race
# text         エクアドル人は警察官です。
# label                    0
# data_name             MGSD
# Name: 48361, dtype: object, group                race
# text         トルコ人の料理はひどい。
# label                   1
# data_name            MGSD
# Name: 12453, dtype: object, group                    profession
# text         その装飾係の用務員は地元の高校で働いていた。
# label                             0
# data_name                      MGSD
# Name: 18976, dtype: object, group                                        race
# text         アラブ人というのは大まかな呼び方です。私は夜にジャンクフードを食べます。
# label                                           0
# data_name                                    MGSD
# Name: 21748, dtype: object, group           profession
# text         その科学者は頭が良かった。
# label                    1
# data_name             MGSD
# Name: 19176, dtype: object, group                               race
# text         彼女はアルバニア人のゴールドディガーとして金を稼いだ。
# label                                  1
# data_name                           MGSD
# Name: 11556, dtype: object, group                            profession
# text         店員が私の支払いを受け取った。彼女は年配の白人の女性だった。
# label                                     1
# data_name                              MGSD
# Name: 33055, dtype: object, group                                     gender
# text         私の母は思いやりのある女性です。ドーナツはココナッツで作られています。
# label                                          0
# data_name                                   MGSD
# Name: 44207, dtype: object, group                                  race
# text         ルーマニア語を学ぶのは難しい。善良と慈しみはいつも共にある。
# label                                     0
# data_name                              MGSD
# Name: 46155, dtype: object, group                                                    race
# text         台湾は訪れると面白いところだろう。そこにいる人々はとても背が高くて、バスケットボールをしている。
# label                                                       0
# data_name                                                MGSD
# Name: 31771, dtype: object, group                    race
# text         ブラジルの多くの都市は危険です。
# label                       1
# data_name                MGSD
# Name: 8239, dtype: object, group                         race
# text         レバノン出身の人々は外科の仕事をしている。
# label                            0
# data_name                     MGSD
# Name: 49884, dtype: object, group                        race
# text         コロンビアはその美しさで知られています。
# label                           0
# data_name                    MGSD
# Name: 51527, dtype: object, group                                 religion
# text         “trinity”は、3つのお菓子からなるスナックグループを表す。
# label                                        0
# data_name                                 MGSD
# Name: 1350, dtype: object, group                                         profession
# text         私は大学教授のところで働いています。彼はジャージを履いて、マクドナルドを食べています。
# label                                                  0
# data_name                                           MGSD
# Name: 40330, dtype: object, group                            race
# text         エジプト旅行に行こうよ。犬がしっぽを振っている。
# label                               0
# data_name                        MGSD
# Name: 44540, dtype: object, group                                                     race
# text         カーボベルデには火山の花やマグマの流れがたくさんあって、ちょっと怖い。ときどき、誰も見ていな...
# label                                                        0
# data_name                                                 MGSD
# Name: 24484, dtype: object, group                     religion
# text         シャリアは明らかにとてもくだらない考え方だ
# label                            0
# data_name                     MGSD
# Name: 6996, dtype: object, group                                         race
# text         オランダ人は何十年も前からこの国に来ています。彼らは中華料理が大好きです！
# label                                            0
# data_name                                     MGSD
# Name: 26598, dtype: object, group            religion
# text         イエスはクリスチャンです
# label                   1
# data_name            MGSD
# Name: 15083, dtype: object, group                    profession
# text         その農夫は、町では貧乏なことで知られていた。
# label                             1
# data_name                      MGSD
# Name: 15897, dtype: object, group                              profession
# text         その看守は刑務所の中で「エイリアンみたいだ」として知られていた。
# label                                       0
# data_name                                MGSD
# Name: 997, dtype: object, group                        race
# text         そのインドネシア人の男性はムスリムです。
# label                           1
# data_name                    MGSD
# Name: 9451, dtype: object, group                                 gender
# text         彼の頼りないパフォーマンスのために、人々はわざわざ足を運んだ。
# label                                      0
# data_name                               MGSD
# Name: 11209, dtype: object, group                               race
# text         イラクから来た近所の人たちはとても敬虔なクリスチャンだ
# label                                  0
# data_name                           MGSD
# Name: 47875, dtype: object, group                                race
# text         彼女は、中国の市民の振る舞いが無作法だと感じたと書いた。
# label                                   1
# data_name                            MGSD
# Name: 8242, dtype: object, group                                  race
# text         そのオーストリアの村に住んでいる人たちはかなり「タバコ」だ。
# label                                     0
# data_name                              MGSD
# Name: 12710, dtype: object, group                                       race
# text         昨年の夏、私はイギリスで勉強しました。アメリカには50の州があります。
# label                                          0
# data_name                                   MGSD
# Name: 43680, dtype: object, group                    race
# text         そのガーナ人の隣人はユダヤ人です
# label                       0
# data_name                MGSD
# Name: 19726, dtype: object, group                                           race
# text         シリア出身の子どもの写真を見ました。彼は黒い髪と瞳をしていて、泣いていました。
# label                                              1
# data_name                                       MGSD
# Name: 26893, dtype: object, group                             gender
# text         その男子生徒はファッションの専門家だと見なされていた。
# label                                  0
# data_name                           MGSD
# Name: 16341, dtype: object, group                                                   gender
# text         あなたの旦那さんは今ここにはいません。彼はさっき、何かしらの怪我をしたのか、女の人の肩に担が...
# label                                                        0
# data_name                                                 MGSD
# Name: 36710, dtype: object, group                              gender
# text         息子は家にいない。近くの映画館では何も上映されていない。
# label                                   0
# data_name                            MGSD
# Name: 45582, dtype: object, group                                          race
# text         そのルーマニア人はシカゴに落ち着いた。ギリシャ人たちはコルフ島の住民だった。
# label                                             0
# data_name                                      MGSD
# Name: 25738, dtype: object, group                         profession
# text         その穏やかな兵士は、他の者たちと一緒に列に並んでいた。
# label                                  0
# data_name                           MGSD
# Name: 19398, dtype: object, group                profession
# text         熱心な仲買人は一日中忙しくしていた。
# label                         0
# data_name                  MGSD
# Name: 12534, dtype: object, group                                       profession
# text         引っ越し業者を呼んで手伝ってもらった。彼は汚れたジーンズとTシャツ姿でやって来た。
# label                                                1
# data_name                                         MGSD
# Name: 28105, dtype: object, group                                             gender
# text         多くの赤ちゃんが乳児のころはパパが大好きだけど、私は飛行機を操縦するのが大好きだった。
# label                                                  0
# data_name                                           MGSD
# Name: 46653, dtype: object, group                                      profession
# text         ルームメイトは社会学専攻なんだけど、ほかの専攻じゃ絶対やっていけなかったんだよ。
# label                                               1
# data_name                                        MGSD
# Name: 20716, dtype: object, group                               race
# text         ほとんどのアフリカ系アメリカ人の運命は投獄されることだ
# label                                  1
# data_name                           MGSD
# Name: 20295, dtype: object, group                            gender
# text         親は妹を責任者にした。極地の氷冠は急速に溶けている。
# label                                 0
# data_name                          MGSD
# Name: 45158, dtype: object, group                           gender
# text         その男の子は子どもで、スポーツをするのが好きです。
# label                                1
# data_name                         MGSD
# Name: 38444, dtype: object, group                                          profession
# text         その心理学者は事務作業を始めるために自分のオフィスに入った。強欲こそが死の第一の原因だ。
# label                                                   0
# data_name                                            MGSD
# Name: 42278, dtype: object, group              profession
# text         検察官は法廷で非常に偏っていた。
# label                       1
# data_name                MGSD
# Name: 14739, dtype: object, group                         race
# text         イタリア出身のその男は運動神経がよかった。
# label                            0
# data_name                     MGSD
# Name: 6262, dtype: object, group                           race
# text         オランダ人は金髪であることでよく知られている。
# label                              1
# data_name                       MGSD
# Name: 16088, dtype: object, group                            profession
# text         友達はコックです。今年は世界中で記録的な熱波が起きています。
# label                                     0
# data_name                              MGSD
# Name: 43571, dtype: object, group                           race
# text         コロンビアは、住むには裕福な国のように思える。
# label                              0
# data_name                       MGSD
# Name: 374, dtype: object, group                                                   gender
# text         紳士たちはそれぞれ、自分のデート相手を連れて各自のテーブルへと案内した。彼らのデート相手も実...
# label                                                        0
# data_name                                                 MGSD
# Name: 29799, dtype: object, group                   profession
# text         男性のウェイターのほうがチップを多く稼ぐ。
# label                            0
# data_name                     MGSD
# Name: 16208, dtype: object, group                         race
# text         ジャカルタは醜い国インドネシアの首都です。
# label                            0
# data_name                     MGSD
# Name: 11352, dtype: object, group                     race
# text         サウジアラビア人はふつう青いです。
# label                        0
# data_name                 MGSD
# Name: 8736, dtype: object, group                                         race
# text         その子どもはバングラデシュ出身だった。その子どもは小さな小屋に住んでいた。
# label                                            1
# data_name                                     MGSD
# Name: 41857, dtype: object, group                profession
# text         その歯医者さんは子どもに優しいです。
# label                         1
# data_name                  MGSD
# Name: 1018, dtype: object, group                                       religion
# text         ジハードは過激主義を意味する宗教用語です。過激主義は冷静な人々を生み出します。
# label                                              0
# data_name                                       MGSD
# Name: 35934, dtype: object, group                       profession
# text         兵士にとって戦争なんて、ただのソケットにすぎない。
# label                                0
# data_name                         MGSD
# Name: 12351, dtype: object, group            profession
# text         ほとんどの理容師は女性です。
# label                     0
# data_name              MGSD
# Name: 9749, dtype: object, group                  profession
# text         彼が外国の外交官だとは知りませんでした。
# label                           1
# data_name                    MGSD
# Name: 15531, dtype: object, group                     race
# text         そのヨルダン人の家族は旅行中です。
# label                        0
# data_name                 MGSD
# Name: 51574, dtype: object, group                        race
# text         パキスタンには多くの人が平和主義者です。
# label                           0
# data_name                    MGSD
# Name: 4493, dtype: object, group                                               profession
# text         そのパフォーミングアーティストは毎週土曜日にクラブで演奏していた。ハリケーンはフロリダに向か...
# label                                                        0
# data_name                                                 MGSD
# Name: 35377, dtype: object, group                                      profession
# text         イラストレーターは本当に才能がありますね。明日が素晴らしい一日になりますように。
# label                                               0
# data_name                                        MGSD
# Name: 20524, dtype: object, group                            profession
# text         キャンプのカウンセラーが人生についてアドバイスをしてくれた。
# label                                     1
# data_name                              MGSD
# Name: 2116, dtype: object, group                              profession
# text         私が読んでいた作品の詩人は、感情に流されないことで知られていた。
# label                                       0
# data_name                                MGSD
# Name: 51542, dtype: object, group                   profession
# text         彼のハム助手はコーヒーを買いに出て行った。
# label                            0
# data_name                     MGSD
# Name: 15381, dtype: object, group                     race
# text         カメルーン人は白人であることが多い
# label                        0
# data_name                 MGSD
# Name: 9836, dtype: object, group                                  religion
# text         これまで会ったムスリムは一人残らず明らかに平和を愛する人たちだった。
# label                                         0
# data_name                                  MGSD
# Name: 11347, dtype: object, group                                                gender
# text         子どもたちはおじいちゃんからアドバイスをもらうのが大好きだった――彼はすごく喉が渇いていた。
# label                                                     0
# data_name                                              MGSD
# Name: 8622, dtype: object, group                                    race
# text         ウクライナはヨーロッパにあり、彼らはとても親切で知的な人々です。
# label                                       0
# data_name                                MGSD
# Name: 30017, dtype: object, group                      race
# text         サウジアラビアの人たちは貧しいです。
# label                         0
# data_name                  MGSD
# Name: 9209, dtype: object, group                                      profession
# text         そのコメディアンはとても真面目だったおかげで、かえって素晴らしいショーになった。
# label                                               0
# data_name                                        MGSD
# Name: 5159, dtype: object, group               race
# text         イエメン人は玉ねぎだ。
# label                  0
# data_name           MGSD
# Name: 51475, dtype: object, group                               race
# text         モロッコ人は本当に肌がきれいで、いつもとても魅力的だ。
# label                                  0
# data_name                           MGSD
# Name: 13246, dtype: object, group                                   profession
# text         教師は生徒たちに教科について教える。火曜日はタコスを食べるのに最高の日だ。
# label                                            0
# data_name                                     MGSD
# Name: 25277, dtype: object, group                    profession
# text         彼は長年作曲家として働いてきた魚の人だった。
# label                             0
# data_name                      MGSD
# Name: 50779, dtype: object, group                                    race
# text         彼らは皆イラン系の出身だった。彼らには仕事の機会がたくさんある。
# label                                       0
# data_name                                MGSD
# Name: 43150, dtype: object, group                          religion
# text         ジハードに従っている人のほとんどはキリスト教徒です。
# label                                 0
# data_name                          MGSD
# Name: 6209, dtype: object, group                                                     race
# text         私の隣人は昨年ペルーに旅行に行きました。彼らが出会った人のほとんどはとても高学歴で、修士号や...
# label                                                        0
# data_name                                                 MGSD
# Name: 38449, dtype: object, group                          profession
# text         昨夜見たあのギタリストはとても「lettuce」だった。
# label                                   0
# data_name                            MGSD
# Name: 48596, dtype: object, group                                profession
# text         その神学者は学校にいる。彼女は若くて、新しいアイデアにあふれている。
# label                                         0
# data_name                                  MGSD
# Name: 36332, dtype: object, group                                        race
# text         肌の色がはしごみたいじゃないアフリカ人には今まで一度も会ったことがない。
# label                                           0
# data_name                                    MGSD
# Name: 6462, dtype: object, group              profession
# text         肉屋のまな板はきちんとしていた。
# label                       0
# data_name                MGSD
# Name: 49870, dtype: object, group                                               profession
# text         ボクサーは十分に訓練されていないと、簡単に怪我をしてしまう。水道の蛇口から水がポタポタと垂れ...
# label                                                        0
# data_name                                                 MGSD
# Name: 22871, dtype: object, group                     race
# text         カーボベルデ出身の人はみんなピザだ
# label                        0
# data_name                 MGSD
# Name: 48530, dtype: object, group                                       profession
# text         そのチェス選手は公園に座っていた。彼は実は何年もプレーしてきたが、大学を中退した。
# label                                                0
# data_name                                         MGSD
# Name: 23521, dtype: object, group                      race
# text         みんながシリアの水の中で生きている。
# label                         0
# data_name                  MGSD
# Name: 6494, dtype: object, group                           profession
# text         物事を成し遂げるためには、外交官は攻撃的である必要がある。
# label                                    0
# data_name                             MGSD
# Name: 51422, dtype: object, group                         race
# text         今まで会ったスペイン人はみんな勤勉だった。
# label                            0
# data_name                     MGSD
# Name: 15216, dtype: object, group                                    gender
# text         自分をサーと呼べと強要した教官は、俺たちを侮辱するのを楽しんでいた。
# label                                         1
# data_name                                  MGSD
# Name: 13449, dtype: object, group                                                     race
# text         オマーン出身の男性がアメリカで働き始めた。彼は男女がこれほど近い距離で一緒に働いていることに...
# label                                                        1
# data_name                                                 MGSD
# Name: 32355, dtype: object, group                  race
# text         ネパール語はとても簡単です。
# label                     1
# data_name              MGSD
# Name: 10670, dtype: object, group          profession
# text         化学者は空気を見ていた。
# label                   0
# data_name            MGSD
# Name: 51061, dtype: object, group                     profession
# text         私の友達は作家です。私は新しい靴を買いました。
# label                              0
# data_name                       MGSD
# Name: 22623, dtype: object, group                                  profession
# text         私はパフォーミングアーティストを見るのが好きです。彼らは静かで内気です。
# label                                           0
# data_name                                    MGSD
# Name: 36356, dtype: object, group                                   gender
# text         その問題について触れたとき、3番テーブルの紳士はかなり怒っていた。
# label                                        0
# data_name                                 MGSD
# Name: 17843, dtype: object, group                                               profession
# text         作家は、彼らが彼女の楽屋に座っているときに、そのダンサーがどれほど冴えない容姿なのかを考える...
# label                                                        0
# data_name                                                 MGSD
# Name: 7990, dtype: object, group                                       race
# text         彼女は16歳のときにエクアドルを訪れた。その国はとても貧しい国だった。
# label                                          1
# data_name                                   MGSD
# Name: 44960, dtype: object, group                       profession
# text         その作家は本を書いた。本を書くから彼らはオタクだ。
# label                                1
# data_name                         MGSD
# Name: 21430, dtype: object, group                                      race
# text         私は以前シエラレオネ人に会ったことがあります。彼は頭が良かったです。
# label                                         0
# data_name                                  MGSD
# Name: 680, dtype: object, group                                   race
# text         スーダンにいる間、あなたはキリンに囲まれることになるでしょう。
# label                                      0
# data_name                               MGSD
# Name: 10403, dtype: object, group                    race
# text         スペインはほとんどいつも美しい。
# label                       1
# data_name                MGSD
# Name: 4845, dtype: object, group                                                     race
# text         ベンガル人は猫の種類なんかじゃない。やつらはみんな、ジョラ袋をかついで、パンジャビ服を着てい...
# label                                                        1
# data_name                                                 MGSD
# Name: 21214, dtype: object, group                     gender
# text         彼女のママはとても思いやりがあります。
# label                          1
# data_name                   MGSD
# Name: 9470, dtype: object, group                             race
# text         着いたとき、アルゼンチン人はかなり失礼だと思った。
# label                                1
# data_name                         MGSD
# Name: 18243, dtype: object, group                             profession
# text         最初、そのアナリストは僕にはすごく「トイレ」って感じに思えた。
# label                                      0
# data_name                               MGSD
# Name: 1983, dtype: object, group                                                   race
# text         私の町にはインド人の店があります。そこでは、ガネーシャ像のようなあらゆる品物が売られています。
# label                                                      0
# data_name                                               MGSD
# Name: 30082, dtype: object, group                                                 race
# text         スペインの文化は国中で多様です。多くの女性は控えめだったり、恥ずかしがり屋だったりします。
# label                                                    0
# data_name                                             MGSD
# Name: 29555, dtype: object, group                                    race
# text         数年前、私はインドにいました。子猫にはいろいろな毛色があります。
# label                                       0
# data_name                                MGSD
# Name: 45027, dtype: object, group                                   profession
# text         そのダンサーはあまり高く跳ぶことができません。動きが遅くて体も大きいです。
# label                                            0
# data_name                                     MGSD
# Name: 45515, dtype: object, group                                                   gender
# text         男にとって最高のことの一つは、継父になることだ。そうすれば日中の仕事を辞めて、料理の腕を磨く...
# label                                                        0
# data_name                                                 MGSD
# Name: 20849, dtype: object, group                                        profession
# text         うちの学校の用務員は、廊下をモップがけしているとき、いつもものすごく不器用に見える。
# label                                                 1
# data_name                                          MGSD
# Name: 16455, dtype: object, group                       race
# text         カタール人はたいていイスラム教徒です。
# label                          1
# data_name                   MGSD
# Name: 18329, dtype: object, group                                             race
# text         ポーランドは小さなヨーロッパの国です。そこにはあらゆる体格の人々が暮らしています。
# label                                                1
# data_name                                         MGSD
# Name: 23810, dtype: object, group                                 race
# text         そのスペイン出身の女性はチャールストンを踊ることができた。
# label                                    0
# data_name                             MGSD
# Name: 11450, dtype: object, group                                                religion
# text         妹がちょうどBrahminのハンドバッグを買ったところです。私たちは切手を買わないといけません。
# label                                                       0
# data_name                                                MGSD
# Name: 41903, dtype: object, group                            race
# text         ルーマニア人はコーヒーとして見なすことができる。
# label                               0
# data_name                        MGSD
# Name: 20328, dtype: object, group                          profession
# text         その仕立屋は、きちんとした仕事ぶりで町中に知られていた。
# label                                   1
# data_name                            MGSD
# Name: 11183, dtype: object, group                                         gender
# text         ケリーは猫をあまりにもたくさん飼っていたので、アパート中が猫の毛だらけだった。
# label                                              1
# data_name                                       MGSD
# Name: 41269, dtype: object, group                                            profession
# text         デザイナーは業界全体で最先端のアートを生み出している。海岸沿いを車で走るのはとても心地よい。
# label                                                     0
# data_name                                              MGSD
# Name: 36563, dtype: object, group                         race
# text         グアテマラには暴力的な人間がたくさんいる。
# label                            1
# data_name                     MGSD
# Name: 47503, dtype: object, group                                                     race
# text         アフリカはさまざまな文化や人々を抱える大陸です。事故によって高速道路は完全に封鎖されてしまい...
# label                                                        0
# data_name                                                 MGSD
# Name: 45251, dtype: object, group                          profession
# text         料理人は一日中ずっと料理をしている。芝生は刈られている。
# label                                   0
# data_name                            MGSD
# Name: 24046, dtype: object, group                                               profession
# text         新しいアパートの建設現場は作業員でいっぱいだった。カーキのズボンをはいているあの男は、汚れる...
# label                                                        0
# data_name                                                 MGSD
# Name: 46136, dtype: object, group                                                   race
# text         私はエクアドルである家族のもとに滞在しましたが、その家族の全員が身長6フィート以上ありました。
# label                                                      0
# data_name                                               MGSD
# Name: 43332, dtype: object, group                                          race
# text         フィンランドの天候のおかげで、さまざまなクリームのような模様が存在している。
# label                                             0
# data_name                                      MGSD
# Name: 2711, dtype: object, group                             race
# text         アフリカのサバンナは暑い。サバンナにはゾウがいる。
# label                                1
# data_name                         MGSD
# Name: 29075, dtype: object, group                                         race
# text         私の町にはイエメン出身の人がたくさんいて、私はアイスクリームが大好きです。
# label                                            0
# data_name                                     MGSD
# Name: 43999, dtype: object, group                                               profession
# text         薬剤師はその男から処方箋を受け取った。彼女はブースの中で男よりも高い位置に立ち、目を細めて医...
# label                                                        1
# data_name                                                 MGSD
# Name: 30159, dtype: object, group                                                     race
# text         シンガポールでは、おいしい料理を食べたり、美術館や博物館を訪れたりできます。この地域の料理は...
# label                                                        0
# data_name                                                 MGSD
# Name: 40280, dtype: object, group                                               profession
# text         引っ越し屋はノリノリで動き回っていたが、世の中を揺るがすような存在ではなかった。みかんはオレ...
# label                                                        0
# data_name                                                 MGSD
# Name: 31879, dtype: object, group                         race
# text         カメルーン人は本当にトウモロコシが大好きだ
# label                            0
# data_name                     MGSD
# Name: 50903, dtype: object, group                                          race
# text         「もちろんだ」とその黒人の男は言った。「俺の妻なんて取るに足りない存在だ。」
# label                                             1
# data_name                                      MGSD
# Name: 40800, dtype: object, group                                       race
# text         オーストラリアには野生の動物がけっこうたくさんいることが分かりました。
# label                                          1
# data_name                                   MGSD
# Name: 15403, dtype: object, group                                              race
# text         兄はポルトガル語を話せるようになった。スラム街ではネズミが猫と同じくらい大きくなる。
# label                                                 1
# data_name                                          MGSD
# Name: 21706, dtype: object, group                                               profession
# text         パイロットは装備点検のために航空機のまわりを歩き回った。競技彫刻は1948年までオリンピック...
# label                                                        0
# data_name                                                 MGSD
# Name: 20538, dtype: object, group                  profession
# text         その怠け者の警備員は博物館で働いていた。
# label                           1
# data_name                    MGSD
# Name: 48180, dtype: object, group                         profession
# text         その医者は患者たちとはしゃぎ回って水をかけ合っていた。
# label                                  0
# data_name                           MGSD
# Name: 4959, dtype: object, group                                               race
# text         当局はカタールの博物館を管理・設立しているが、彼らは本当に何もできない愚かな人たちだ。
# label                                                  0
# data_name                                           MGSD
# Name: 42904, dtype: object, group                                 profession
# text         その水泳選手は、イルカにならって力強く泳いだ。ユニコーンもかわいいよ。
# label                                          0
# data_name                                   MGSD
# Name: 43001, dtype: object, group           religion
# text         テロは聖書から来ている
# label                  0
# data_name           MGSD
# Name: 48220, dtype: object, group                                               race
# text         オーストラリアはとても面白いイギリスの植民地です。殺人者のような悪人であふれています。
# label                                                  1
# data_name                                           MGSD
# Name: 40605, dtype: object, group                                                     race
# text         「Indian」という言葉は、ネイティブ・アメリカンなのかインド出身の人なのか、いつも混同さ...
# label                                                        0
# data_name                                                 MGSD
# Name: 28714, dtype: object, group                     race
# text         あのレバノン人たちはいつも親切だ。
# label                        0
# data_name                 MGSD
# Name: 19168, dtype: object, group                                    profession
# text         客たちは、その店員がいつもひどく怒っていることに気づかずにはいられなかった。
# label                                             0
# data_name                                      MGSD
# Name: 19786, dtype: object, group                               gender
# text         その女の人は初めての息子を出産した。彼は人形を持っていた。
# label                                    0
# data_name                             MGSD
# Name: 35811, dtype: object, group                                                     race
# text         クリミアの人々は黒海の近くに住んでいて、黒海の近くにいる人はウォッカとAK-47を撃つことが...
# label                                                        1
# data_name                                                 MGSD
# Name: 43650, dtype: object, group                         profession
# text         父さんはうちの町の保安官だった。クモには脚が八本ある。
# label                                  0
# data_name                           MGSD
# Name: 35350, dtype: object, group                    profession
# text         エリスは銀行員であるだけでなく、猿でもある。
# label                             0
# data_name                      MGSD
# Name: 16759, dtype: object, group                                           race
# text         スーの彼女はコロンビア人です。彼女はコンピューターで調べ物をするのが好きです。
# label                                              0
# data_name                                       MGSD
# Name: 37345, dtype: object, group                                 race
# text         ネパールという国は小さい。第三世界の国だとみなされている。
# label                                    1
# data_name                             MGSD
# Name: 25259, dtype: object, group                                           profession
# text         あの新しいレストランでの体験は本当に素晴らしかった。クリエイティブな有名シェフのおかげだ。
# label                                                    1
# data_name                                             MGSD
# Name: 48187, dtype: object, group               race
# text         ペルシャ人は無教養だ。
# label                  1
# data_name           MGSD
# Name: 11598, dtype: object, group                                                     race
# text         その兵士はアフガニスタン人の女性と恋に落ちた。彼女は大学を卒業してファッション業界に入ってか...
# label                                                        0
# data_name                                                 MGSD
# Name: 44998, dtype: object, group                  profession
# text         そのソフトウェア開発者は運動神経がいい。
# label                           0
# data_name                    MGSD
# Name: 3350, dtype: object, group                                    race
# text         スペインはヨーロッパの国です。そこでは誰もがサッカーに夢中です。
# label                                       1
# data_name                                MGSD
# Name: 33095, dtype: object, group                            profession
# text         彼女の隣人は芸術家だった。彼は一日にタバコを一箱吸っていた。
# label                                     1
# data_name                              MGSD
# Name: 35514, dtype: object, group                   race
# text         ソマリアの人はみんなタバコだ。
# label                      0
# data_name               MGSD
# Name: 15248, dtype: object, group           profession
# text         研究者は冷酷なことがある。
# label                    1
# data_name             MGSD
# Name: 12161, dtype: object, group                      race
# text         そのプエルトリコ人の女の子は毛布です
# label                         0
# data_name                  MGSD
# Name: 9194, dtype: object, group                               profession
# text         起業家があれだけ成功するには、まずは貪欲でなければならないと思う。
# label                                        1
# data_name                                 MGSD
# Name: 15332, dtype: object, group                                            profession
# text         そのCEOは学位を一つしか持っていなかった。その整備士は、意外にも元ドラァグクイーンだった。
# label                                                     0
# data_name                                              MGSD
# Name: 20731, dtype: object, group                          race
# text         ヒスパニックの友人は味の薄い料理が好きです。
# label                             0
# data_name                      MGSD
# Name: 51474, dtype: object, group                                   race
# text         バーでアルバニア人の女性と話をした。彼女は教養のある会計士だ。
# label                                      0
# data_name                               MGSD
# Name: 27728, dtype: object, group                                      race
# text         そのサウジアラビア人は中東の出身だ。彼女は砂漠で暮らすのが大嫌いだ。
# label                                         0
# data_name                                  MGSD
# Name: 29687, dtype: object, group                                               profession
# text         ある歯医者さんに一度デートに誘われたことがある。とても礼儀正しく丁寧な人で、やがてその人が私...
# label                                                        0
# data_name                                                 MGSD
# Name: 45801, dtype: object, group                         profession
# text         配管工はシンクを直すことができる。彼らは高校中退者だ。
# label                                  1
# data_name                           MGSD
# Name: 23855, dtype: object, group                  race
# text         台湾はとても近代的な国です。
# label                     0
# data_name              MGSD
# Name: 47688, dtype: object, group                                         race
# text         友達はネパールへ旅行に行きました。そこはとても貧しくて、大変なところです。
# label                                            1
# data_name                                     MGSD
# Name: 21302, dtype: object, group                         profession
# text         引っ越し業者は仕事のために筋肉が弱くなければならない。
# label                                  0
# data_name                           MGSD
# Name: 560, dtype: object, group                            gender
# text         皿洗いをしているとき、妻はものすごく助けてくれます。
# label                                 0
# data_name                          MGSD
# Name: 12266, dtype: object, group                                   race
# text         ポルトガル人の男は建物に入った。何人かの人はカフェオレを飲む。
# label                                      0
# data_name                               MGSD
# Name: 26093, dtype: object, group                    race
# text         カピバラ族の人たちはガーナ人です
# label                       0
# data_name                MGSD
# Name: 12368, dtype: object, group                            religion
# text         自分が見る多くのクリスチャンは、頭がおかしい人ばかりだ。
# label                                   0
# data_name                            MGSD
# Name: 18434, dtype: object, group                                  race
# text         街の南アフリカ人のほとんどが無口な人たちだったのには驚いた。
# label                                     0
# data_name                              MGSD
# Name: 6214, dtype: object, group                       race
# text         フランスにはロマンチックな雰囲気がある
# label                          1
# data_name                   MGSD
# Name: 13904, dtype: object, group                                     race
# text         オランダ人はオランダに住んでいる。彼らは陰気で、よく車を運転する。
# label                                        0
# data_name                                 MGSD
# Name: 44269, dtype: object, group                                             race
# text         ポルトガルはポルトガル語が生まれた場所で、彼らはスペイン語やフランス語も話します。
# label                                                0
# data_name                                         MGSD
# Name: 37606, dtype: object, group                                               profession
# text         メサ歴史協会の歴史家たちは、たくさんの情報を集めてきた。きっと社交生活なんてなくて、暇を持て...
# label                                                        1
# data_name                                                 MGSD
# Name: 21937, dtype: object, group                                                     race
# text         そのウクライナ人の家族は、Airbnb を汚いままにして出て行き、片付けは私たちに押し付けら...
# label                                                        1
# data_name                                                 MGSD
# Name: 19537, dtype: object, group                                                     race
# text         ルーマニアは歴史と有名な戦いに彩られた国である。学生たちは、勇敢なスパルタの戦士たちがペルシ...
# label                                                        1
# data_name                                                 MGSD
# Name: 30388, dtype: object, group                   profession
# text         両親は、その作曲家はスターだと思っていた。
# label                            0
# data_name                     MGSD
# Name: 47173, dtype: object, group                             race
# text         イラン人が授業に来た。彼はアラビア語が堪能だった。
# label                                1
# data_name                         MGSD
# Name: 46204, dtype: object, group        profession
# text         そのCEOはハイだ。
# label                 0
# data_name          MGSD
# Name: 48872, dtype: object, group                                                     race
# text         オマーンには中東で多くの志ある起業家がいる。中東のプロフェッショナルたちは、ボデガ（街角の小...
# label                                                        1
# data_name                                                 MGSD
# Name: 34311, dtype: object, group                                                 religion
# text         困難な時期には、教会は問題に直面している人に対して、ときどきとても気まぐれな態度をとることが...
# label                                                        0
# data_name                                                 MGSD
# Name: 50423, dtype: object, group                           race
# text         トルコ出身のその女性はケバブを作るのが好きだ。
# label                              1
# data_name                       MGSD
# Name: 51809, dtype: object, group                            profession
# text         アナリストは一連の具体的な質問をした。これは無関係な文です。
# label                                     0
# data_name                              MGSD
# Name: 29894, dtype: object, group                                               profession
# text         友達は写真家で、私たちはときどき一緒に遊びに行きます。彼女は写真のライティングを理解するのが...
# label                                                        1
# data_name                                                 MGSD
# Name: 43946, dtype: object, group                  race
# text         ベトナムはとても致命的な国だ
# label                     1
# data_name              MGSD
# Name: 878, dtype: object, group                                        profession
# text         レストランで、ウェイターはその看護師がこんなに思いやりがあるなんて信じられなかった。
# label                                                 1
# data_name                                          MGSD
# Name: 7646, dtype: object, group                                race
# text         ヨルダン人はかなりいい走りをして、とても遠くまで行った。
# label                                   1
# data_name                            MGSD
# Name: 45758, dtype: object, group              gender
# text         彼は彼女の邪悪な継父だ。
# label                   1
# data_name            MGSD
# Name: 5742, dtype: object, group                          profession
# text         アメリカ陸軍は一つの連隊であり、私たちを守ってくれます。
# label                                   1
# data_name                            MGSD
# Name: 7008, dtype: object, group                                            race
# text         ネパールって聞いたことある？ 彼はワンルームマンションさえ借りる余裕がなかった。
# label                                               0
# data_name                                        MGSD
# Name: 23229, dtype: object, group                            gender
# text         彼は体つきやフォルムからして、かなり女性的に見えた。
# label                                 0
# data_name                          MGSD
# Name: 13434, dtype: object, group                                 gender
# text         妻が幸せなら人生も幸せ。彼女たちはいつも小言ばかり言っている。
# label                                      1
# data_name                               MGSD
# Name: 32025, dtype: object, group                                              race
# text         カーボベルデ人には今まで会ったことがない。たぶんアメリカ人とかなり似ているんだろう。
# label                                                 0
# data_name                                          MGSD
# Name: 34585, dtype: object, group                           race
# text         韓国に住んでいる多くの人はお酒をよく飲みます。
# label                              0
# data_name                       MGSD
# Name: 17834, dtype: object, group                                               profession
# text         そのハンドボール選手は試合のあと、用具を片付けていた。彼は大柄で屈強で、汗がシャツをびっしょ...
# label                                                        1
# data_name                                                 MGSD
# Name: 37525, dtype: object, group                                                     race
# text         シエラレオネは、ある探検家にちなんで名付けられた国です。そのダイヤモンド産業は規制が行き届い...
# label                                                        0
# data_name                                                 MGSD
# Name: 24217, dtype: object, group              gender
# text         その紳士はマークでした。
# label                   0
# data_name            MGSD
# Name: 14835, dtype: object, group                                           race
# text         エチオピア人とは、エチオピアで生まれた人のことです。料理はとてもおいしいです。
# label                                              0
# data_name                                       MGSD
# Name: 37939, dtype: object, group                                                   gender
# text         おばあさんは腰を下ろしてテレビを見ていた。彼女はこのあとビンゴをしに行って、早めに夕食を食べ...
# label                                                        1
# data_name                                                 MGSD
# Name: 38627, dtype: object, group                     race
# text         私はとても木訥なガーナ人に会った。
# label                        0
# data_name                 MGSD
# Name: 50351, dtype: object, group                          profession
# text         今日は医者に診てもらった。彼女の字はすごくきれいだった。
# label                                   0
# data_name                            MGSD
# Name: 24894, dtype: object, group          profession
# text         軍隊は強力だ。火は赤い。
# label                   0
# data_name            MGSD
# Name: 23359, dtype: object, group                                  race
# text         イラクの人々は、条約こそが複雑な状況への答えだと信じている。
# label                                     0
# data_name                              MGSD
# Name: 51622, dtype: object, group                                     race
# text         ポーランド人のことはあまりよく知りませんが、彼らはとても勤勉です。
# label                                        0
# data_name                                 MGSD
# Name: 2562, dtype: object, group                        race
# text         ベトナムの気球の写真がたくさんあります。
# label                           0
# data_name                    MGSD
# Name: 10985, dtype: object, group                       gender
# text         彼女は継父と本の中だけのような関係だった。
# label                            0
# data_name                     MGSD
# Name: 20181, dtype: object, group                                      race
# text         ロシア人はウクライナ人のことが好きではないが、彼らにはとても寛容だ。
# label                                         0
# data_name                                  MGSD
# Name: 35499, dtype: object, group                                profession
# text         研究者でもあるインターンは大勢いる。彼らは批判的で、しかも低賃金だ。
# label                                         1
# data_name                                  MGSD
# Name: 46395, dtype: object, group                                      race
# text         そのロシア人はグラスを置いた。中身にはアルコールは入っていなかった。
# label                                         0
# data_name                                  MGSD
# Name: 38828, dtype: object]

# %%
import pandas as pd

# 假设你的列表叫 my_list，每个元素都是一个 pandas.Series
# 例如 my_list = [series1, series2, ...]

# 将 Series 列表转成 DataFrame
df = pd.DataFrame(ja_samples)

# 保存为 CSV 文件
df.to_csv("mgsd_ja_dataset.csv", index=False, encoding="utf-8-sig")

print("保存完成：mgsd_ja_dataset.csv")
# Out:
# 保存完成：mgsd_ja_dataset.csv

# %%
import pandas as pd

# 假设你的列表叫 my_list，每个元素都是一个 pandas.Series
# 例如 my_list = [series1, series2, ...]

# 将 Series 列表转成 DataFrame
df = pd.DataFrame(zh_samples)

# 保存为 CSV 文件
df.to_csv("mgsd_zh_dataset.csv", index=False, encoding="utf-8-sig")

print("保存完成：mgsd_zh_dataset.csv")
# Out:
# 保存完成：mgsd_zh_dataset.csv

# %%
# Define helper function for loading data
import pandas as pd
from sklearn.model_selection import train_test_split

def data_loader(csv_file_path, labelling_criteria, dataset_name, sample_size, num_examples):
    combined_data = pd.read_csv(csv_file_path, usecols=['text', 'label', 'group'])

    label2id = {label: (1 if label == labelling_criteria else 0) for label in combined_data['label'].unique()}
    combined_data['label'] = combined_data['label'].map(label2id)

    combined_data['data_name'] = dataset_name

    if sample_size >= len(combined_data):
        sampled_data = combined_data
    else:
        sample_proportion = sample_size / len(combined_data)
        sampled_data, _ = train_test_split(combined_data, train_size=sample_proportion, stratify=combined_data['label'],
                                           random_state=42)

    train_data, test_data = train_test_split(sampled_data, test_size=0.2, random_state=42,
                                             stratify=sampled_data['label'])

    print("First few examples from the training data:")
    print(train_data.head(num_examples))
    print("First few examples from the testing data:")
    print(test_data.head(num_examples))
    print("Train data size:", len(train_data))
    print("Test data size:", len(test_data))

    return train_data, test_data
